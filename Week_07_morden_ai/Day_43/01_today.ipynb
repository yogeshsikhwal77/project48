# %% [markdown]
# ## History of ai

# %% [markdown]
# ### Encoder Decoder detailed maths working architecture and improvement

# %% [markdown]
# ### Attention Mechanism

# %% [markdown]
# ### Bahdanau Attention VS Luong Attention
