# %% [markdown]
# # main heading
# ## subheading
# ### small heading
#
# this is a regular text
#
# ---
#
# - task list 1
# - task list 2

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world
