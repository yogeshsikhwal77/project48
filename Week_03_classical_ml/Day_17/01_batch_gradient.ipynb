# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=True)
reg = LinearRegression()
reg.fit(X_train,y_train)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [ -30.62219046 -272.2506057   528.85252681  327.69716891 -581.01973841
#   332.97061365  -27.97314298  139.28036115  665.07667773   61.90517166]
# 151.4300932966009

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4384316213369278

# %%
class GdRegressor:

    def __init__(self,learning_rate=0.01,epochs=100):
        self.coef_ = None 
        self.intercept_ = None 
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self,X_train,y_train):
        # init my coef
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        for i in range(self.epochs):
            # update all the coef and the intercept
            y_hat = np.dot(X_train,self.coef_) + self.intercept_  #vectorization
            intercept_der = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)
            coef_der = -2 * np.dot((y_train - y_hat),X_train)/X_train.shape[0]
            self.coef_ = self.coef_ - (self.lr * coef_der)

        print(self.intercept_,self.coef_)

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
gdr = GdRegressor(epochs=10000,learning_rate=0.5)
import time 
start = time.time()
gdr.fit(X_train,y_train)
print("TIME TAKEN:",time.time() - start)
# Out:
# 151.36313237453808 [ -30.93455317 -269.89542     534.53673161  324.96608829 -127.6573365
#   -27.42328478 -227.40229118   88.69559016  493.03845516   63.84419576]
# TIME TAKEN: 0.249525785446167

# %%
y_pred1 = gdr.predict(X_test)
print(r2_score(y_test,y_pred1))
# Out:
# 0.42968657115339237
