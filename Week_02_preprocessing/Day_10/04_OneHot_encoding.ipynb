# %% [markdown]
# ## ONE HOT Encoding

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Kia                 4
# Ambassador          4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %% [markdown]
# ###  1.One hot encoding through pandas

# %%
pd.get_dummies(df,columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# ### 2.K-1 One hot encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
# ...

# %% [markdown]
# ### 3. One hot encoding through sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=True)
X_test.head()
# Out:
#          brand  km_driven    fuel        owner
# 1392  Mahindra      80000  Diesel  First Owner
# 7778      Tata      45000  Diesel  First Owner
# 3727   Hyundai      60000  Diesel  First Owner
# 6630      Tata      15000  Petrol  First Owner
# 103     Maruti     100000  Petrol  Third Owner

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first',dtype=np.int32)
X_train_new = ohe.fit_transform(X_train[['fuel','owner']]).toarray()
X_test_new = ohe.transform(X_test[['fuel','owner']]).toarray()
X_train_new.shape
# Out:
# (6502, 7)

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new))
# Out:
# array([['Honda', 100000, 1, ..., 1, 0, 0],
#        ['Maruti', 120000, 1, ..., 1, 0, 0],
#        ['Renault', 100000, 1, ..., 1, 0, 0],
#        ...,
#        ['Hyundai', 70000, 0, ..., 0, 0, 0],
#        ['Maruti', 110000, 1, ..., 1, 0, 0],
#        ['Maruti', 65755, 0, ..., 0, 0, 0]], shape=(6502, 9), dtype=object)

# %%
### 4.ONE hot encoding with top categories

# %%
counts = df['brand'].value_counts()
df['brand'].nunique()
threshold =100
repl = counts[counts<= threshold].index
pd.get_dummies(df['brand'].replace(repl,'uncommon')).sample(7)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 3739  False      False  False  False    False     False    True    False
# 1192  False      False  False  False    False     False   False    False
# 3681  False      False  False  False    False     False    True    False
# 1316  False      False  False  False    False     False    True    False
# 5071  False      False   True  False    False     False   False    False
# 3443  False      False  False  False    False     False   False    False
# 4828  False      False  False  False     True     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 3739  False  False   False       False     False
# 1192  False  False    True       False     False
# 3681  False  False   False       False     False
# 1316  False  False   False       False     False
# 5071  False  False   False       False     False
# 3443  False  False    True       False     False
# ...
