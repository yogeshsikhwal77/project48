# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN,Dense

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data(num_words=10000)

x_train = pad_sequences(X_train,maxlen=100)
x_test = pad_sequences(X_test,maxlen=100)

# %%
model = Sequential([
    Embedding(10000,32,input_length=100),
    SimpleRNN(5,return_sequences=True),
    SimpleRNN(5),
    Dense(1,activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 32)           320000
#
#  simple_rnn_2 (SimpleRNN)    (None, 100, 5)            190
#
#  simple_rnn_3 (SimpleRNN)    (None, 5)                 55
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 320,251
# Trainable params: 320,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(x_train,y_train,epochs=5,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 136s 209ms/step - loss: 0.5482 - accuracy: 0.7282 - val_loss: 0.4660 - val_accuracy: 0.7986
# Epoch 2/5
# 625/625 [==============================] - 146s 233ms/step - loss: 0.3682 - accuracy: 0.8498 - val_loss: 0.4436 - val_accuracy: 0.8020
# Epoch 3/5
# 625/625 [==============================] - 110s 177ms/step - loss: 0.2509 - accuracy: 0.9057 - val_loss: 0.4664 - val_accuracy: 0.8068
# Epoch 4/5
# 625/625 [==============================] - 89s 143ms/step - loss: 0.1698 - accuracy: 0.9406 - val_loss: 0.5361 - val_accuracy: 0.7974
# Epoch 5/5
# 625/625 [==============================] - 259s 415ms/step - loss: 0.1089 - accuracy: 0.9660 - val_loss: 0.6802 - val_accuracy: 0.7730
